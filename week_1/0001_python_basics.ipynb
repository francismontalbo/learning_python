# %% [markdown]
# # Python Basics — Week 1
#
# Welcome to the first step in the course. This notebook introduces the core language features you will use everywhere else in Python.

# %% [markdown]
# ## Learning goals
#
# By the end of this notebook, you should be able to:
# - run simple Python statements
# - use comments effectively
# - create variables with clear names
# - work with numbers, text, and Boolean values
# - combine variables into readable output

# %% [markdown]
# ## How to learn from this notebook
#
# Run every code cell in order. Then change at least one value in each section. That small habit turns passive reading into real learning.

# %%
print("Hello, Python learner!")
print("You are beginning with the same building blocks used in real programs.")

# %% [markdown]
# ## Comments explain intent
#
# A good comment explains *why* something matters, not what is already obvious from the code.

# %%
# This message introduces the learner to Python output.
print("Comments make notebooks easier to understand.")

# Uncomment the next line if you want to test another output.
# print("I am practicing by editing code.")

# %% [markdown]
# ## Variables store information
#
# Variables let us name data so we can reuse it later.

# %%
student_name = "Avery"
study_hours = 2
confidence_score = 8.5
is_ready_to_practice = True

print(student_name)
print(study_hours)
print(confidence_score)
print(is_ready_to_practice)

# %% [markdown]
# ## Checking data types
#
# Python can tell us what kind of value a variable currently holds.

# %%
print(type(student_name))
print(type(study_hours))
print(type(confidence_score))
print(type(is_ready_to_practice))

# %% [markdown]
# ## Numbers in Python
#
# You will often work with whole numbers (`int`) and decimal numbers (`float`).

# %%
whole_number = 12
decimal_number = 12.75

print(whole_number, type(whole_number))
print(decimal_number, type(decimal_number))

# %% [markdown]
# ## Text in Python
#
# Strings store text. They are used for names, labels, messages, and many kinds of program output.

# %%
course_title = "Python Foundations"
lesson_message = "Readable code is a professional habit."

print(course_title)
print(lesson_message)

# %% [markdown]
# ## Arithmetic operators
#
# Let us use arithmetic to model a simple study scenario.

# %%
weekly_goal = 20
completed_lessons = 7
remaining_lessons = weekly_goal - completed_lessons
practice_sets = 3 * 4
average_score = 17 / 4
whole_groups = 17 // 4
leftover_items = 17 % 4
power_result = 2 ** 5

print("Remaining lessons:", remaining_lessons)
print("Practice sets:", practice_sets)
print("Average score:", average_score)
print("Whole groups:", whole_groups)
print("Leftover items:", leftover_items)
print("2 to the power of 5:", power_result)

# %% [markdown]
# ## Updating variables
#
# Programs often change values as work gets completed.

# %%
completed_lessons = completed_lessons + 3
study_hours += 1

print("Updated completed lessons:", completed_lessons)
print("Updated study hours:", study_hours)

# %% [markdown]
# ## f-strings for readable output
#
# F-strings help us mix variables and text cleanly.

# %%
summary = f"{student_name} studied for {study_hours} hours and completed {completed_lessons} lessons."
print(summary)

# %% [markdown]
# ## Bringing earlier topics together
#
# Here we combine variables, arithmetic, and strings in one short example.

# %%
price_per_book = 14.99
number_of_books = 3
total_cost = price_per_book * number_of_books

receipt = f"Buying {number_of_books} books costs ${total_cost:.2f}."
print(receipt)

# %% [markdown]
# ## Mini review
#
# Before moving on, make sure you can explain:
# - what a variable is
# - the difference between `int` and `float`
# - how `type()` helps
# - why f-strings are useful

# %% [markdown]
# ## Practice prompts
#
# 1. Create a variable for your favorite topic.
# 2. Create two number variables and print their sum.
# 3. Write an f-string that introduces yourself as a Python learner.
